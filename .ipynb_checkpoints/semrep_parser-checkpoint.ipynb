# %%
from xml.etree.ElementTree import ElementTree

# %%
def parse_semrep_xmp(file_name):
    semrep_output = ElementTree().parse(file_name)
    for document in semrep_output:
        for semrep_tag in document:
            for utterance in semrep_tag:
                if utterance.tag == 'Predication':
                    print(utterance.tag)
                else:
                    print(utterance.tag)

# %%
file_name = 'semrep_output.xml'
parse_semrep_xmp(file_name)
# Out:
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Entity
# Predication

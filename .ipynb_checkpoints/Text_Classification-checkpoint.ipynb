# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, xgboost, numpy, textblob, string

# %%
import os
import os.path

def get_files(target_dir):
    item_list = os.listdir(target_dir)

    file_list = list()
    for item in item_list:
        item_dir = os.path.join(target_dir,item)
        if os.path.isdir(item_dir):
            file_list += get_files(item_dir)
        else:
            file_list.append(item_dir)
    return file_list

# %%
target_pos_dir = 'data/AMD'
all_files_pos = get_files(target_pos_dir)
target_neg_dir = 'data/NON-AMD'
all_files_neg = get_files(target_neg_dir)
all_files = all_files_pos + all_files_neg

# %%
# load the positive dataset
labels, texts = [], []
for file in all_files:
    data = open(file).read()
    if file in all_files_pos:
        labels.append('AMD')
        texts.append(data)
    else:
        labels.append('NON-AMD')
        texts.append(data)

# create a dataframe using texts and lables
trainDF = pandas.DataFrame()
trainDF['text'] = texts
trainDF['label'] = labels
trainDF = trainDF.sample(frac=1).reset_index(drop=True)
trainDF
# Out:
#                                                   text    label
# 0    To determine the repeatability of measuring th...      AMD
# 1    This retrospective cohort study examines the a...      AMD
# 2    Autoimmune diseases are characterized by an ex...  NON-AMD
# 3    To evaluate baseline and treatment factors inf...      AMD
# 4    The association between fish consumption and r...      AMD
# 5    An understanding of etiological and maintainin...  NON-AMD
# 6    Age-related macular cegeneration (AMD) is the ...      AMD
# 7    This study determined whether FCGR3B copy numb...  NON-AMD
# 8    Optical coherence tomography angiography is on...      AMD
# 9    Financial burden from cancer treatment is incr...  NON-AMD
# 10   Although obesity and insulin resistance are cl...  NON-AMD
# 11   Age-related macular degeneration (AMD) is one ...      AMD
# 12   Intravitreal injections of anti-vascular endot...      AMD
# 13   To investigate thiol/disulfide status using a ...      AMD
# 14   Smoking has been identified as a major modifia...      AMD
# 15   Antagonism of the gastric inhibitory polypepti...  NON-AMD
# 16   Systemic VEGF inhibition disrupts endothelial ...      AMD
# 17   To evaluate pentraxin3 (PTX3) levels in patien...      AMD
# 18   Diabesity (obesity and diabetes mellitus) has ...  NON-AMD
# 19   Age-related macular degeneration (AMD) is the ...      AMD
# 20   Oxidative stress was predominantly involved in...  NON-AMD
# 21   To present the clinical relevance of the anato...      AMD
# 22   Research on the quality of life (QL) of childr...  NON-AMD
# 23   <b>Objective:</b> To explore the effect of fin...  NON-AMD
# 24   Obsessive-compulsive disorder (OCD) is a distr...  NON-AMD
# 25   Various in vitro culture systems have been use...      AMD
# 26   To clarify the efficacy of aflibercept for tre...      AMD
# 27   To evaluate whether drusen of subjects with fi...      AMD
# 28   Metallothioneins (MTs) are a family of low mol...  NON-AMD
# 29   Oxidative stress has been considered as a majo...  NON-AMD
# ..                                                 ...      ...
# 970  Age-related macular degeneration (AMD) is the ...      AMD
# 971  Prehypertension and hypertension in childhood ...  NON-AMD
# 972  The aim of this study was to investigate the p...      AMD
# 973  Paracetamol (APAP) is one of the most widely u...  NON-AMD
# 974  One-third of men with obesity or type 2 diabet...  NON-AMD
# 975  Background We evaluated the association of car...  NON-AMD
# 976  To describe bridge arch-shaped serous retinal ...      AMD
# 977  The aim of the present study was to estimate t...  NON-AMD
# 978  This study aimed to explore whether functional...  NON-AMD
# 979  The aim of this study was to find predictive f...      AMD
# 980  After a pilot study on skin cancer screening w...  NON-AMD
# 981  Clinical application of the major anticancer d...  NON-AMD
# 982  Augmented Reality is a new technological syste...  NON-AMD
# 983  The aim of this study was to investigate the o...      AMD
# 984  Age-related macular degeneration (AMD) is the ...      AMD
# 985  To evaluate the 6-month safety and efficacy of...      AMD
# 986  Many retinal specialists have utilized intravi...      AMD
# 987  Previous studies on the relationship between a...  NON-AMD
# 988  To assess choroidal thickness (CT) and its rel...      AMD
# 989  Department of Defense lands are essential for ...  NON-AMD
# 990  High arterial stiffness seems to be causally i...  NON-AMD
# 991  The aim of this communication was to evaluate ...      AMD
# 992  Especially when chronic, the presence of a som...  NON-AMD
# 993  Age-related macular degeneration (ARMD), a pro...      AMD
# 994  Family accommodation in obsessive-compulsive d...  NON-AMD
# 995  Psychological disturbances play an increasingl...  NON-AMD
# 996  Patients with cancer who are infected with the...  NON-AMD
# 997  To compare the effects of converting to aflibe...      AMD
# 998  Obesity, characterized by low grade inflammati...  NON-AMD
# 999  Research indicates that patients with Obsessiv...  NON-AMD
#
# [1000 rows x 2 columns]

# %%
# split the dataset into training and validation datasets 
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'])

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

# %%
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(trainDF['text'])
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# ngram level tf-idf 
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram.fit(trainDF['text'])
xtrain_tfidf_ngram =  tfidf_vect_ngram.transform(train_x)
xvalid_tfidf_ngram =  tfidf_vect_ngram.transform(valid_x)

# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(trainDF['text'])
xtrain_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(train_x) 
xvalid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(valid_x)
# Out:
# <750x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 726676 stored elements in Compressed Sparse Row format>

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

# %%
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
count_vect.fit(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xvalid_count =  count_vect.transform(valid_x)

# %%
trainDF['char_count'] = trainDF['text'].apply(len)
trainDF['word_count'] = trainDF['text'].apply(lambda x: len(x.split()))
trainDF['word_density'] = trainDF['char_count'] / (trainDF['word_count']+1)
trainDF['punctuation_count'] = trainDF['text'].apply(lambda x: len("".join(_ for _ in x if _ in string.punctuation))) 
trainDF['title_word_count'] = trainDF['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.istitle()]))
trainDF['upper_case_word_count'] = trainDF['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.isupper()]))
trainDF
# Out:
#                                                   text    label  char_count  \
# 0    To determine the repeatability of measuring th...      AMD        1652
# 1    This retrospective cohort study examines the a...      AMD        1553
# 2    Autoimmune diseases are characterized by an ex...  NON-AMD         911
# 3    To evaluate baseline and treatment factors inf...      AMD        1698
# 4    The association between fish consumption and r...      AMD        1730
# 5    An understanding of etiological and maintainin...  NON-AMD        2292
# 6    Age-related macular cegeneration (AMD) is the ...      AMD         984
# 7    This study determined whether FCGR3B copy numb...  NON-AMD        1485
# 8    Optical coherence tomography angiography is on...      AMD        1448
# 9    Financial burden from cancer treatment is incr...  NON-AMD        1147
# 10   Although obesity and insulin resistance are cl...  NON-AMD        1696
# 11   Age-related macular degeneration (AMD) is one ...      AMD        1338
# 12   Intravitreal injections of anti-vascular endot...      AMD        1686
# 13   To investigate thiol/disulfide status using a ...      AMD        1685
# 14   Smoking has been identified as a major modifia...      AMD        1542
# 15   Antagonism of the gastric inhibitory polypepti...  NON-AMD        1892
# 16   Systemic VEGF inhibition disrupts endothelial ...      AMD        1473
# 17   To evaluate pentraxin3 (PTX3) levels in patien...      AMD         939
# 18   Diabesity (obesity and diabetes mellitus) has ...  NON-AMD        1447
# 19   Age-related macular degeneration (AMD) is the ...      AMD        1766
# 20   Oxidative stress was predominantly involved in...  NON-AMD        1978
# 21   To present the clinical relevance of the anato...      AMD        1006
# 22   Research on the quality of life (QL) of childr...  NON-AMD        1117
# 23   <b>Objective:</b> To explore the effect of fin...  NON-AMD        2202
# 24   Obsessive-compulsive disorder (OCD) is a distr...  NON-AMD        1395
# 25   Various in vitro culture systems have been use...      AMD        1055
# 26   To clarify the efficacy of aflibercept for tre...      AMD        1487
# 27   To evaluate whether drusen of subjects with fi...      AMD        1639
# 28   Metallothioneins (MTs) are a family of low mol...  NON-AMD        1883
# 29   Oxidative stress has been considered as a majo...  NON-AMD        1516
# ..                                                 ...      ...         ...
# 970  Age-related macular degeneration (AMD) is the ...      AMD        1683
# 971  Prehypertension and hypertension in childhood ...  NON-AMD        1841
# 972  The aim of this study was to investigate the p...      AMD        1399
# 973  Paracetamol (APAP) is one of the most widely u...  NON-AMD        1584
# 974  One-third of men with obesity or type 2 diabet...  NON-AMD        1508
# 975  Background We evaluated the association of car...  NON-AMD        2137
# 976  To describe bridge arch-shaped serous retinal ...      AMD        1701
# 977  The aim of the present study was to estimate t...  NON-AMD        1421
# 978  This study aimed to explore whether functional...  NON-AMD        1562
# 979  The aim of this study was to find predictive f...      AMD        1612
# 980  After a pilot study on skin cancer screening w...  NON-AMD        2130
# 981  Clinical application of the major anticancer d...  NON-AMD        1030
# 982  Augmented Reality is a new technological syste...  NON-AMD        1340
# 983  The aim of this study was to investigate the o...      AMD        1550
# 984  Age-related macular degeneration (AMD) is the ...      AMD        1277
# 985  To evaluate the 6-month safety and efficacy of...      AMD        1707
# 986  Many retinal specialists have utilized intravi...      AMD        1237
# 987  Previous studies on the relationship between a...  NON-AMD        1250
# 988  To assess choroidal thickness (CT) and its rel...      AMD        1333
# 989  Department of Defense lands are essential for ...  NON-AMD        2098
# 990  High arterial stiffness seems to be causally i...  NON-AMD        1793
# 991  The aim of this communication was to evaluate ...      AMD        1372
# 992  Especially when chronic, the presence of a som...  NON-AMD        1119
# 993  Age-related macular degeneration (ARMD), a pro...      AMD        1651
# 994  Family accommodation in obsessive-compulsive d...  NON-AMD        1704
# 995  Psychological disturbances play an increasingl...  NON-AMD        1422
# 996  Patients with cancer who are infected with the...  NON-AMD        2180
# 997  To compare the effects of converting to aflibe...      AMD        1344
# 998  Obesity, characterized by low grade inflammati...  NON-AMD        1455
# 999  Research indicates that patients with Obsessiv...  NON-AMD        1592
#
#      word_count  word_density  punctuation_count  title_word_count  \
# 0           256      6.428016                 47                20
# 1           220      7.027149                 72                14
# 2           127      7.117188                 15                 6
# 3           245      6.902439                 78                21
# 4           269      6.407407                118                14
# 5           311      7.346154                 42                27
# 6           138      7.079137                 20                 5
# 7           198      7.462312                145                 9
# 8           197      7.313131                 21                 6
# 9           165      6.909639                 18                 9
# 10          249      6.784000                 78                15
# 11          200      6.656716                 56                12
# 12          232      7.236052                 55                13
# 13          278      6.039427                122                10
# 14          249      6.168000                 73                15
# 15          245      7.691057                144                 9
# 16          200      7.328358                 37                21
# 17          146      6.387755                 47                 6
# 18          198      7.271357                 53                14
# 19          251      7.007937                 50                11
# 20          270      7.298893                 73                27
# 21          148      6.751678                 23                 7
# 22          153      7.253247                 23                 8
# 23          301      7.291391                159                25
# 24          199      6.975000                 25                 5
# 25          149      7.033333                 32                 7
# 26          248      5.971888                 58                10
# 27          248      6.582329                 82                19
# 28          277      6.773381                 80                17
# 29          227      6.649123                 30                12
# ..          ...           ...                ...               ...
# 970         251      6.678571                 57                22
# 971         260      7.053640                105                19
# 972         221      6.301802                 51                23
# 973         238      6.627615                 33                 7
# 974         222      6.762332                 36                12
# 975         300      7.099668                 92                18
# 976         233      7.269231                 53                11
# 977         202      7.000000                 89                16
# 978         237      6.563025                119                16
# 979         232      6.918455                 59                 7
# 980         311      6.826923                 77                37
# 981         142      7.202797                 30                 5
# 982         202      6.600985                 21                20
# 983         249      6.200000                106                21
# 984         198      6.417085                 22                 7
# 985         231      7.357759                 73                14
# 986         179      6.872222                 29                 8
# 987         175      7.102273                 27                15
# 988         201      6.599010                 67                 6
# 989         302      6.924092                 71                17
# 990         247      7.229839                 84                21
# 991         204      6.692683                 37                24
# 992         149      7.460000                 19                 7
# 993         245      6.711382                 99                 8
# 994         221      7.675676                 41                 8
# 995         204      6.936585                 32                17
# 996         318      6.833856                147                24
# 997         186      7.187166                 28                12
# 998         211      6.863208                 34                10
# 999         218      7.269406                 28                11
#
#      upper_case_word_count
# 0                       21
# 1                       11
# 2                        0
# 3                       13
# 4                       27
# 5                        3
# 6                        6
# 7                       39
# 8                        1
# 9                        0
# 10                      14
# 11                      14
# 12                       0
# 13                      17
# 14                      13
# 15                       6
# 16                       4
# 17                      15
# 18                       3
# 19                      15
# 20                      11
# 21                       7
# 22                       9
# 23                      12
# 24                      13
# 25                       8
# 26                      19
# 27                      21
# 28                      22
# 29                      10
# ..                     ...
# 970                     29
# 971                      0
# 972                     13
# 973                     11
# 974                      6
# 975                      2
# 976                      8
# 977                     10
# 978                     37
# 979                     22
# 980                     11
# 981                      5
# 982                      2
# 983                     10
# 984                      9
# 985                      5
# 986                      6
# 987                      7
# 988                     25
# 989                     11
# 990                      4
# 991                      7
# 992                      0
# 993                     20
# 994                      8
# 995                      4
# 996                     12
# 997                      0
# 998                     12
# 999                      5
#
# [1000 rows x 8 columns]

# %%
# Naive Bayes on Count Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, train_y, xvalid_count)
print("NB, Count Vectors: ", accuracy)

# Naive Bayes on Word Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print("NB, WordLevel TF-IDF: ", accuracy)

# Naive Bayes on Ngram Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print("NB, N-Gram Vectors: ", accuracy) 

# Naive Bayes on Character Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram_chars, train_y, xvalid_tfidf_ngram_chars)
print("NB, CharLevel Vectors: ", accuracy)
# Out:
# NB, Count Vectors:  1.0
# NB, WordLevel TF-IDF:  0.996
# NB, N-Gram Vectors:  0.988
# NB, CharLevel Vectors:  0.968

# %%
# Linear Classifier on Count Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_count, train_y, xvalid_count)
print("LR, Count Vectors: ", accuracy)

# Linear Classifier on Word Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf, train_y, xvalid_tfidf)
print("LR, WordLevel TF-IDF: ", accuracy) 

# Linear Classifier on Ngram Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print("LR, N-Gram Vectors: ", accuracy) 

# Linear Classifier on Character Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram_chars, train_y, xvalid_tfidf_ngram_chars)
print("LR, CharLevel Vectors: ", accuracy)
# Out:
# LR, Count Vectors:  1.0
# LR, WordLevel TF-IDF:  0.984
# LR, N-Gram Vectors:  0.988
# LR, CharLevel Vectors:  0.992

# %%
# SVM on Ngram Level TF IDF Vectors
accuracy = train_model(svm.SVC(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print("SVM, N-Gram Vectors: ", accuracy)
# Out:
# SVM, N-Gram Vectors:  0.46

# %%
# RF on Count Vectors
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_count, train_y, xvalid_count)
print("RF, Count Vectors: ", accuracy) 

# RF on Word Level TF IDF Vectors
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print("RF, WordLevel TF-IDF: ", accuracy)
# Out:
# RF, Count Vectors:  0.972
# RF, WordLevel TF-IDF:  0.992

# %%
# Extereme Gradient Boosting on Count Vectors
accuracy = train_model(xgboost.XGBClassifier(), xtrain_count.tocsc(), train_y, xvalid_count.tocsc())
print("Xgb, Count Vectors: ", accuracy)

# Extereme Gradient Boosting on Word Level TF IDF Vectors
accuracy = train_model(xgboost.XGBClassifier(), xtrain_tfidf.tocsc(), train_y, xvalid_tfidf.tocsc())
print("Xgb, WordLevel TF-IDF: ", accuracy) 

# Extereme Gradient Boosting on Character Level TF IDF Vectors
accuracy = train_model(xgboost.XGBClassifier(), xtrain_tfidf_ngram_chars.tocsc(), train_y, xvalid_tfidf_ngram_chars.tocsc())
print("Xgb, CharLevel Vectors: ", accuracy)
# Out:
# /home/sid/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Xgb, Count Vectors:  0.996
# /home/sid/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Xgb, WordLevel TF-IDF:  0.996
# Xgb, CharLevel Vectors:  0.996
# /home/sid/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
